# %%
import heliolinc3d as hl
import heliolinc3d.heliolinc3d_v2 as hl2

# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
import logging
warnings.filterwarnings('ignore')

# %%
from numba import njit

# %%
logger = logging.getLogger()
logger.setLevel( logging.INFO )
logging.debug(' initilizing logger...')

# %%
dfObs = pd.read_csv( '../neos_mbas_1month.csv')

# %%
# get a 14 day window
mjd_start = dfObs[ 'FieldMJD_TAI'].min()
mjd_stop = mjd_start + 14.0
dfObs = dfObs[ dfObs['FieldMJD_TAI'] <= mjd_stop ]
mjd_ref = 0.5*(mjd_start + mjd_stop)

# %%
dfObs.reset_index( inplace=True )
dfObs.rename( 
    columns = {
        'FieldMJD_TAI' : 'FieldMJD',
        'index' : 'obsName' 
    }, 
    inplace=True )

# %%
dfHeliolincInput=hl.obs2heliolinc(dfObs)
# add observer states for observation epochs
dfHeliolincInput[['x_obs','y_obs','z_obs']], dfHeliolincInput[['vx_obs','vy_obs','vz_obs']] = hl.getObserverStates(
    dfHeliolincInput['time'],
    origin='SSB',
    observer_location='X05',
    ephemeris_dt='1h',
    frame='ecliptic'
    )
dfHeliolincInput['night'] = hl.whichNight(dfHeliolincInput['time'])

# %%
dfHeliolincInput
# Out:
#           obsName          time          RA        DEC    obsId     x_obs  \
# 0               0  60796.013231  210.812507 -73.626046        0 -0.760799
# 1               1  60796.037691  210.781540 -73.625285        1 -0.760535
# 2               2  60796.097231  169.145905  -7.835319        2 -0.759887
# 3               3  60796.120341  169.149066  -7.826511        3 -0.759634
# 4               4  60796.120791  168.356483 -10.641907        4 -0.759629
# ...           ...           ...         ...        ...      ...       ...
# 6202912  11927698  60808.160981  201.954568 -10.274897  6202912 -0.613102
# 6202913  11927699  60808.185011  201.958576 -10.271149  6202913 -0.612779
# 6202914  11927700  60809.096001  187.341383   7.238919  6202914 -0.600577
# 6202915  11927701  60809.100931  180.363544  -5.266361  6202915 -0.600510
# 6202916  11927702  60809.173631  202.157157 -10.122016  6202916 -0.599521
#
#             y_obs     z_obs    vx_obs    vy_obs    vz_obs  night
# 0       -0.649628 -0.000151  0.010797 -0.013326  0.000083  60796
# 1       -0.649954 -0.000148  0.010835 -0.013335  0.000089  60796
# 2       -0.650749 -0.000143  0.010934 -0.013334  0.000093  60796
# 3       -0.651057 -0.000141  0.010973 -0.013326  0.000091  60796
# 4       -0.651063 -0.000141  0.010974 -0.013326  0.000091  60796
# ...           ...       ...       ...       ...       ...    ...
# 6202912 -0.794164 -0.000120  0.013463 -0.010748  0.000074  60808
# 6202913 -0.794422 -0.000119  0.013493 -0.010721  0.000064  60808
# 6202914 -0.803944 -0.000125  0.013545 -0.010570  0.000090  60809
# 6202915 -0.803996 -0.000124  0.013553 -0.010568  0.000089  60809
# 6202916 -0.804762 -0.000118  0.013657 -0.010502  0.000068  60809
#
# [6202917 rows x 12 columns]

# %%
# fig = px.scatter( dfHeliolincInput['RA'], dfHeliolincInput['DEC'] )

# %%
# fig.show()

# %%
# pairs = hl2.makeTracklets( 
#     dfHeliolincInput['RA'].to_numpy() ,
#     dfHeliolincInput['DEC'].to_numpy() ,
#     dfHeliolincInput['time'].to_numpy() ,
#     max_vel=3.5, # deg/day
#     max_time=2.0/24.0, # days
#     )

# x, v, dt, pairs = hl2.make_heliocentric_arrows( 
#     dfHeliolincInput['RA'].to_numpy() ,
#     dfHeliolincInput['DEC'].to_numpy() ,
#     dfHeliolincInput['time'].to_numpy() ,
#     dfHeliolincInput[['x_obs', 'y_obs', 'z_obs',]].to_numpy(),
#     pairs,
#     1.3,
#     0.0,
#     mjd_ref,
#     max_vel=0.05, # AU / day
#     )

# %%
# mjd_ref = 0.5*(dfHeliolincInput['time'].to_numpy().max() + dfHeliolincInput['time'].to_numpy().min())
# arrows = hl2.make_heliocentric_arrows_2(
#     dfHeliolincInput['RA'].to_numpy() ,
#     dfHeliolincInput['DEC'].to_numpy() ,
#     dfHeliolincInput['time'].to_numpy() ,
#     dfHeliolincInput[['x_obs', 'y_obs', 'z_obs',]].to_numpy(),
#     1.3,
#     0.0,
#     mjd_ref,
#     max_vel=0.05,
#     max_trk_time=2.0/24.0,
# )

# %%
dfHeliolincInput[['x_obs', 'y_obs', 'z_obs',]].values.T
# Out:
# array([[-7.60799297e-01, -7.60534736e-01, -7.59886668e-01, ...,
#         -6.00577085e-01, -6.00510287e-01, -5.99521059e-01],
#        [-6.49628377e-01, -6.49954450e-01, -6.50748522e-01, ...,
#         -8.03944247e-01, -8.03996352e-01, -8.04762467e-01],
#        [-1.50563912e-04, -1.48460181e-04, -1.42987832e-04, ...,
#         -1.24549215e-04, -1.24108222e-04, -1.18309197e-04]])

# %%
dbscan_fit, L_A, pairs = hl2.heliolinc3d(
    dfHeliolincInput['RA'].to_numpy() ,
    dfHeliolincInput['DEC'].to_numpy() ,
    dfHeliolincInput['time'].to_numpy() ,
    dfHeliolincInput[['x_obs', 'y_obs', 'z_obs',]].to_numpy().T,
    1.2,
    0.0,
    # cr=0.00001
    cr=0.0001
)
# Out:
# INFO:heliolinc3d.heliolinc3d_v2: calculating arrows...
# INFO:heliolinc3d.heliolinc3d_v2: tracklet search radius: 0.0047140452079103175 AU
# INFO:heliolinc3d.heliolinc3d_v2: KD-tree construction time: 2.2483949661254883 s
# INFO:heliolinc3d.heliolinc3d_v2: KD-tree construction time: 3.229146957397461 s
# INFO:heliolinc3d.heliolinc3d_v2: found 2 potential pairs
# INFO:heliolinc3d.heliolinc3d_v2: found 1432530 valid pairs
# INFO:heliolinc3d.heliolinc3d_v2: found 1310894 valid pairs after velocity cut
# INFO:heliolinc3d.heliolinc3d_v2: clustering angular momentum and eccentricity...

# %%
dbscan_fit
# Out:
# HDBSCAN(cluster_selection_epsilon=1e-05, min_samples=3)

# %%
tracklets = pd.DataFrame({
    'observation_1'   : pairs[0],
    'observation_1_id': dfObs.iloc[ pairs[0] ]['ObjID'].values,
    'observation_2'   : pairs[1],
    'observation_2_id': dfObs.iloc[ pairs[1] ]['ObjID'].values,
    'l_x'             : L_A[0],
    'l_y'             : L_A[1],
    'l_z'             : L_A[2],
    'e_x'             : L_A[3],
    'e_y'             : L_A[4],
    'e_z'             : L_A[5],
    'cluster'         : dbscan_fit.labels_
})
tracklets = tracklets[ tracklets['cluster'] != -1 ]
tracklets
# Out:
#          observation_1 observation_1_id  observation_2 observation_2_id  \
# 22                8773          G376174           8774          G376174
# 39              753755        S1009Tuda         753756        S1009Tuda
# 45              754362        S1009Tuda         754364        S1009Tuda
# 47              754358        S1009Tuda         754359        S1009Tuda
# 48              754357        S1009Tuda         754359        S1009Tuda
# ...                ...              ...            ...              ...
# 1310843        1867543        S1001r0Ga        1867608        S1001r0Ga
# 1310861        5164679        S1004xj9a        5164732        S1004xj9a
# 1310868        5873549        S1005YW5a        5873595        S1005YW5a
# 1310884        2944883        S100273Da        2944955        S100273Da
# 1310885        2944809        S100273Da        2944883        S100273Da
#
#               l_x       l_y       l_z       e_x       e_y       e_z  cluster
# 22       0.001731 -0.006300  0.012829  0.009974  0.009788  0.003461      109
# 39      -0.002058 -0.002743  0.017882  0.006604  0.016642  0.003313      904
# 45      -0.001987 -0.002849  0.017928  0.006279  0.016814  0.003368      904
# 47      -0.002073 -0.002736  0.017921  0.006424  0.016757  0.003301      904
# 48      -0.002047 -0.002771  0.017925  0.006346  0.016789  0.003320      904
# ...           ...       ...       ...       ...       ...       ...      ...
# 1310843  0.000838  0.001796  0.000364 -0.001749  0.000903 -0.000429     3422
# 1310861  0.001226  0.002053 -0.000378 -0.002066  0.001130 -0.000563     2552
# 1310868  0.000907  0.001824  0.000331 -0.001754  0.000964 -0.000504     3422
# 1310884  0.001439  0.001984 -0.001525 -0.002491  0.001299 -0.000661     2579
# 1310885  0.001106  0.001531 -0.001163 -0.001914  0.000999 -0.000506     2750
#
# [546282 rows x 11 columns]

# %%
tracklet_clusters = tracklets.groupby( 'cluster' )
tracklet_clusters

# %%
pairs_idx = np.array([[i,i] for i in range(pairs.shape[1])]).flatten()
obs_idx = pairs.flatten()
cluster_obs = pd.DataFrame({
    'obs_id' : obs_idx,
    'trk_idx' : pairs_idx,
    'cluster': dbscan_fit.labels_[ pairs_idx ],
    'obj_id' : dfObs.iloc[obs_idx]['ObjID'].values,
})
cluster_obs = cluster_obs[ cluster_obs['cluster'] != -1 ]
cluster_obs
# Out:
#          obs_idx  trk_idx  cluster     obs_id
# 44        754363       22      109  S1009Tuda
# 45        754362       22      109  S1009Tuda
# 78       4065765       39      904  S100364ta
# 79       4065764       39      904  S100364ta
# 90       1850785       45      904  S100ghGea
# ...          ...      ...      ...        ...
# 2621737  1867608  1310868     3422  S1001r0Ga
# 2621768   297599  1310884     2579  S1000ITMa
# 2621769   297672  1310884     2579  S1000ITMa
# 2621770  3466359  1310885     2750  S1002wrqa
# 2621771  3466301  1310885     2750  S1002wrqa
#
# [1092564 rows x 4 columns]

# %%
for cluster in cluster_obs:
    print( cluster )
# Out:
# obs_idx
# trk_idx
# cluster
# obs_id

# %%
pairs.flatten()
# Out:
# array([   7124, 2329249, 2329432, ..., 3942301, 1750973, 1750910])

# %%
len( np.unique(dbscan_fit.labels_) )
# Out:
# 41307

# %%
len(L_E[:,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 len(L_E[:,0])
#
# NameError: name 'L_E' is not defined

# %%
len(np.unique(dbscan_fit.labels_))
# Out:
# 19607

# %%
len( dbscan_fit.labels_ ), len( L_E )
# Out:
# (2318452, 2318452)

# %%
@njit
def calculate_mean_states_2( labels, points ):
    n = len(np.unique(labels)) - 1
    d = points.shape[1]

    # logger.info( f' {n} clusters with {6} dimensions' )

    counts = np.zeros( n )
    mean_states = np.zeros( (n, d), dtype=points.dtype, )

    for label, point in zip(labels, points):
        mean_states[ label ] += point
        counts[ label ] += 1
    
    # mean_states /= counts
    return (mean_states.T / counts).T, counts
    # return mean_states, counts

# %%
def check_pairs( names, pairs ):
    mismatch = np.where( names[pairs[:, 0]] != names[pairs[:, 1]] )
    logger.info( f' {len(mismatch[0])} bad tracklets' )
    # if len(mismatch) == 1:
        # logger.info( f' at {mismatch[0]}' )

# %%
check_pairs( dfObs['ObjID'].values, pairs )
# Out:
# INFO:root: 152553 bad tracklets

# %%
# def collect_clusters( labels, pairs, points, names ):

#     clusters = { label: {
#         'ids': [],
#         'n_trks': 0,
#         'rating': 0,
#         'mean_state'
#     } for label in np.unique(labels)[1:]  }

#     for label, pair in zip(labels, pairs):
#         if label != -1:
#             ids = names[ pair ]
#             clusters[ label ][ 'ids' ].append( ids )
#             clusters[ label ][ 'n_trks' ] += 1

#             mean_state = np.mean(  )

#     clusters =  { label : {
#         'ids': np.unique( clusters[ label ]['ids'] ),
#         'n_trks': clusters[ label ]['n_trks'],
#         'rating': len(np.unique( clusters[ label ]['ids'] )),
#         'sigma_r': 
#     } for label in clusters.keys() }

#     return clusters

# %%
clusters = collect_clusters( dbscan_fit.labels_, pairs, dbscan_fit.components_, dfObs['ObjID'].values )
len( clusters)
# Out:
# 19606

# %%
clusters
# Out:
# {0: {'ids': array(['S1000c0va'], dtype=object), 'n_trks': 3, 'rating': 1},
#  1: {'ids': array(['S10030jAa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  2: {'ids': array(['S100eOFLa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  3: {'ids': array(['S1005gE5a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  4: {'ids': array(['S1001xdQa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  5: {'ids': array(['S1001kyMa', 'S100iyhWa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  6: {'ids': array(['S1007GPJa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  7: {'ids': array(['S1000zBma', 'S100uTyza'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  8: {'ids': array(['S1004iDOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  9: {'ids': array(['S1003ToVa', 'S1009vkFa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  10: {'ids': array(['S1001Jrta'], dtype=object), 'n_trks': 3, 'rating': 1},
#  11: {'ids': array(['S100553Za'], dtype=object), 'n_trks': 4, 'rating': 1},
#  12: {'ids': array(['S1004ctSa', 'S100hlpla'], dtype=object),
#   'n_trks': 6,
#   'rating': 2},
#  13: {'ids': array(['S1000ntWa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  14: {'ids': array(['S100m2wba'], dtype=object), 'n_trks': 5, 'rating': 1},
#  15: {'ids': array(['S1000q1ta'], dtype=object), 'n_trks': 3, 'rating': 1},
#  16: {'ids': array(['S1002P7Xa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  17: {'ids': array(['S100f7F4a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  18: {'ids': array(['S1003Xiya'], dtype=object), 'n_trks': 4, 'rating': 1},
#  19: {'ids': array(['S100gfrPa', 'S100gsYLa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#
], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  244: {'ids': array(['S1000Aula', 'S100daKDa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  245: {'ids': array(['S1003MsCa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  246: {'ids': array(['S1003lOJa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  247: {'ids': array(['S1009O2pa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  248: {'ids': array(['S1002TnRa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  249: {'ids': array(['S1003nwja', 'S100mGV2a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  250: {'ids': array(['S1000DC8a', 'S1001iaVa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  251: {'ids': array(['S1000Yqya', 'S100u3nNa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  252: {'ids': array(['S1009EGia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  253: {'ids': array(['S100IjR6a', 'S100klLwa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  254: {'ids': array(['S1009xoca'], dtype=object), 'n_trks': 3, 'rating': 1},
#  255: {'ids': array(['S1003ZzHa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  256: {'ids': array(['S100a7OWa', 'S100up41a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  257: {'ids': array(['S1001Ukqa', 'S1002Mn7a', 'S100nEY2a', 'S100qlHva'], dtype=object),
#   'n_trks': 2381,
#   'rating': 4},
#  258: {'ids': array(['S1002hE3a', 'S1002sVPa', 'S10066oEa', 'S1009QWZa', 'S100aT3ba',
#          'S100bSkla', 'S100gswja', 'S100xp53a'], dtype=object),
#   'n_trks': 300,
#   'rating': 8},
#  259: {'ids': array(['S10007ula', 'S1000Gr4a', 'S10012UIa', 'S10014Kla', 'S1001hXwa',
#          'S1001vx9a', 'S1003Kqaa', 'S1003lTKa', 'S1003oCna', 'S1003q0ya',
#          'S1004t1Fa', 'S1005s5oa', 'S1005u9Ba', 'S10062zPa', 'S10066waa',
#          'S1006Aqya', 'S1006M1Ra', 'S1007EQAa', 'S1007KHca', 'S1008XnDa',
#          'S1009Va3a', 'S100Aasra', 'S100Ecaqa', 'S100EeE1a', 'S100G8vKa',
#          'S100QQSba', 'S100aQRua', 'S100akLba', 'S100c8DJa', 'S100cRsDa',
#          'S100dG1za', 'S100dz4ha', 'S100eswOa', 'S100gYAKa', 'S100gkzWa',
#          'S100hcLua', 'S100hnWEa', 'S100ivtQa', 'S100iybFa', 'S100ka58a',
#          'S100mu1za', 'S100ni8ba', 'S100nv6ea', 'S100pGjPa', 'S100q30Fa',
#          'S100qWdFa', 'S100rcNda', 'S1012YCwa'], dtype=object),
#   'n_trks': 17056,
#   'rating': 48},
#  260: {'ids': array(['S1003yX0a', 'S1005I6Da', 'S100CEhTa', 'S100DJFMa', 'S100FYtJa',
#          'S100au1Da', 'S100bF9va', 'S100czPTa', 'S100daoEa', 'S100g9pza',
#          'S100iruia', 'S100klLOa', 'S100kv8Ba', 'S100ldnca', 'S100nZrRa'],
#         dtype=object),
#   'n_trks': 1085,
#   'rating': 15},
#  261: {'ids': array(['S100280Sa', 'S100bBEha', 'S100qMACa', 'S100wFRPa'], dtype=object),
#   'n_trks': 144,
#   'rating': 4},
#  262: {'ids': array(['S1000ATDa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  263: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  264: {'ids': array(['S1006RfCa', 'S1006dQAa', 'S100ayMUa', 'S100hPPFa', 'S100jOZva',
#          'S100sI1la'], dtype=object),
#   'n_trks': 252,
#   'rating': 6},
#  265: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  266: {'ids': array(['S1006RfCa', 'S100ayMUa', 'S100jOZva', 'S100vOnna'], dtype=object),
#   'n_trks': 325,
#   'rating': 4},
#  267: {'ids': array(['S100ayMUa', 'S100jOZva'], dtype=object),
#   'n_trks': 10,
#   'rating': 2},
#  268: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  269: {'ids': array(['S1006RfCa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  270: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  271: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 6,
#   'rating': 2},
#  272: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 7, 'rating': 1},
#  273: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  274: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  275: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  276: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 289, 'rating': 1},
#  277: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 89, 'rating': 1},
#  278: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  279: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 10, 'rating': 1},
#  280: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  281: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  282: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  283: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  284: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  285: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 8, 'rating': 1},
#  286: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  287: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  288: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  289: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  290: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  291: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  292: {'ids': array(['S100bPlMa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  293: {'ids': array(['S1002YOIa', 'S100BzSma', 'S100bPlMa', 'S100hxmYa', 'S100jOZva',
#          'S100mdvpa'], dtype=object),
#   'n_trks': 469,
#   'rating': 6},
#  294: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  295: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 194, 'rating': 1},
#  296: {'ids': array(['S1004xu6a', 'S100hVyZa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  297: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 8, 'rating': 1},
#  298: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  299: {'ids': array(['S100hPPFa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  300: {'ids': array(['S100hPPFa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  301: {'ids': array(['S100BzSma', 'S100bPlMa', 'S100hPPFa', 'S100mdvpa'], dtype=object),
#   'n_trks': 42,
#   'rating': 4},
#  302: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  303: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  304: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 14, 'rating': 1},
#  305: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 6, 'rating': 1},
#  306: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  307: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  308: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  309: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  310: {'ids': array(['S100hPPFa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  311: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  312: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  313: {'ids': array(['S100Fbtoa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  314: {'ids': array(['S1006RfCa', 'S1007s4Sa', 'S100N0QFa', 'S100arfSa', 'S100ayMUa',
#          'S100hxmYa', 'S100jOZva'], dtype=object),
#   'n_trks': 1541,
#   'rating': 7},
#  315: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  316: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  317: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  318: {'ids': array(['S1006RfCa', 'S100jOZva'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  319: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  320: {'ids': array(['S100jOZva', 'S100sI1la'], dtype=object),
#   'n_trks': 278,
#   'rating': 2},
#  321: {'ids': array(['S100jOZva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  322: {'ids': array(['S1001HQXa', 'S1003vw8a', 'S1006Sv1a', 'S1007s4Sa', 'S1009Mnra',
#          'S100LncOa', 'S100aPbZa', 'S100rwlPa', 'S100tM77a', 'S100vOnna'],
#         dtype=object),
#   'n_trks': 1119,
#   'rating': 10},
#  323: {'ids': array(['S1001HQXa', 'S1001tvaa', 'S1002YOIa', 'S1003vw8a', 'S1003wKVa',
#          'S1009Bg3a', 'S1009Mnra', 'S100BvJXa', 'S100QvQpa', 'S100aCAea',
#          'S100cRDla', 'S100gTIUa', 'S100gm5Ga', 'S100tM77a', 'S100ysz0a'],
#         dtype=object),
#   'n_trks': 1110,
#   'rating': 15},
#  324: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  325: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  326: {'ids': array(['S1004xu6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  327: {'ids': array(['S1002E4Ka', 'S1003vw8a', 'S1003wKVa', 'S1004xu6a', 'S100Pw8xa',
#          'S100cRDla', 'S100febha', 'S100qi1xa', 'S100tM77a', 'S100xE20a'],
#         dtype=object),
#   'n_trks': 1626,
#   'rating': 10},
#  328: {'ids': array(['S1001tvaa', 'S1003vw8a', 'S1003wKVa'], dtype=object),
#   'n_trks': 17,
#   'rating': 3},
#  329: {'ids': array(['S1003vw8a', 'S1004ezOa', 'S100BvJXa', 'S100LncOa'], dtype=object),
#   'n_trks': 360,
#   'rating': 4},
#  330: {'ids': array(['S1001tvaa', 'S1003vw8a'], dtype=object),
#   'n_trks': 6,
#   'rating': 2},
#  331: {'ids': array(['S1001tvaa', 'S1003vw8a', 'S100LncOa', 'S100gm5Ga', 'S100ysz0a'],
#         dtype=object),
#   'n_trks': 768,
#   'rating': 5},
#  332: {'ids': array(['S1003vw8a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  333: {'ids': array(['S1003vw8a'], dtype=object), 'n_trks': 9, 'rating': 1},
#  334: {'ids': array(['S1003vw8a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  335: {'ids': array(['S1004a9ta'], dtype=object), 'n_trks': 7, 'rating': 1},
#  336: {'ids': array(['S1004a9ta'], dtype=object), 'n_trks': 18, 'rating': 1},
#  337: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 149, 'rating': 1},
#  338: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 47, 'rating': 1},
#  339: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  340: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  341: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  342: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  343: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 8, 'rating': 1},
#  344: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  345: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  346: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  347: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  348: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  349: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  350: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  351: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  352: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  353: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  354: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  355: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  356: {'ids': array(['S100arfSa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  357: {'ids': array(['S100mdvpa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  358: {'ids': array(['S100mdvpa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  359: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  360: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  361: {'ids': array(['S1001HQXa', 'S1004au6a', 'S1006Sv1a', 'S1006dQAa', 'S1007rPba',
#          'S1007s4Sa', 'S1008WtKa', 'S1008s62a', 'S1009Mnra', 'S100aPbZa',
#          'S100cIYoa', 'S100icNca', 'S100jKVVa', 'S100mdvpa', 'S100qqVza',
#          'S100rwlPa', 'S100vOnna'], dtype=object),
#   'n_trks': 3683,
#   'rating': 17},
#  362: {'ids': array(['S100BzSma', 'S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  363: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  364: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  365: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  366: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  367: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  368: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  369: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  370: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  371: {'ids': array(['S100bPlMa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  372: {'ids': array(['S100bPlMa', 'S100mdvpa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  373: {'ids': array(['S1001HQXa', 'S1001tvaa', 'S1002YOIa', 'S100LncOa', 'S100ysz0a'],
#         dtype=object),
#   'n_trks': 356,
#   'rating': 5},
#  374: {'ids': array(['S1001HQXa', 'S1007s4Sa', 'S1009Mnra'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  375: {'ids': array(['S1001HQXa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  376: {'ids': array(['S1001HQXa', 'S1007s4Sa', 'S100rwlPa'], dtype=object),
#   'n_trks': 10,
#   'rating': 3},
#  377: {'ids': array(['S1001HQXa', 'S1003vw8a', 'S1009Mnra'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  378: {'ids': array(['S1001HQXa', 'S1009Mnra'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  379: {'ids': array(['S1001HQXa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  380: {'ids': array(['S1001HQXa', 'S1009Mnra'], dtype=object),
#   'n_trks': 16,
#   'rating': 2},
#  381: {'ids': array(['S1001HQXa', 'S1008s62a', 'S1009Mnra', 'S100rwlPa'], dtype=object),
#   'n_trks': 4,
#   'rating': 4},
#  382: {'ids': array(['S1001HQXa', 'S1009Mnra', 'S100rwlPa'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  383: {'ids': array(['S1009Mnra', 'S100rwlPa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  384: {'ids': array(['S1009Mnra', 'S100rwlPa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  385: {'ids': array(['S1001HQXa', 'S100rwlPa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  386: {'ids': array(['S100rwlPa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  387: {'ids': array(['S1007s4Sa', 'S100rwlPa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  388: {'ids': array(['S1001HQXa', 'S1008s62a', 'S100gm5Ga', 'S100rwlPa'], dtype=object),
#   'n_trks': 376,
#   'rating': 4},
#  389: {'ids': array(['S1008s62a', 'S100rwlPa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  390: {'ids': array(['S100rwlPa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  391: {'ids': array(['S1003vw8a', 'S100LncOa', 'S1014j2ya'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  392: {'ids': array(['S1003vw8a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  393: {'ids': array(['S1001tvaa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  394: {'ids': array(['S1001tvaa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  395: {'ids': array(['S1001tvaa', 'S1004ezOa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  396: {'ids': array(['S1001tvaa', 'S1003vw8a'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  397: {'ids': array(['S1001tvaa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  398: {'ids': array(['S1002E4Ka', 'S100lHIra'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  399: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 6, 'rating': 1},
#  400: {'ids': array(['S1002E4Ka', 'S1003wKVa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  401: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 4, 'rating': 1},
#  402: {'ids': array(['S1002E4Ka', 'S1003wKVa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  403: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 3, 'rating': 1},
#  404: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 4, 'rating': 1},
#  405: {'ids': array(['S1002E4Ka', 'S1003wKVa', 'S100Pw8xa'], dtype=object),
#   'n_trks': 5,
#   'rating': 3},
#  406: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 4, 'rating': 1},
#  407: {'ids': array(['S1002E4Ka'], dtype=object), 'n_trks': 4, 'rating': 1},
#  408: {'ids': array(['S100CJvNa', 'S100cRDla'], dtype=object),
#   'n_trks': 643,
#   'rating': 2},
#  409: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 15, 'rating': 1},
#  410: {'ids': array(['S100CJvNa', 'S100febha'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  411: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  412: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  413: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  414: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  415: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  416: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  417: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  418: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  419: {'ids': array(['S100CJvNa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  420: {'ids': array(['S1002E4Ka', 'S100gm5Ga'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  421: {'ids': array(['S1007vuWa', 'S100ayMUa'], dtype=object),
#   'n_trks': 8,
#   'rating': 2},
#  422: {'ids': array(['S100ayMUa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  423: {'ids': array(['S100ayMUa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  424: {'ids': array(['S1006dQAa', 'S100aPbZa', 'S100vOnna'], dtype=object),
#   'n_trks': 6,
#   'rating': 3},
#  425: {'ids': array(['S1006RfCa', 'S100ayMUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  426: {'ids': array(['S1006dQAa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  427: {'ids': array(['S100hxmYa'], dtype=object), 'n_trks': 6, 'rating': 1},
#
'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  484: {'ids': array(['S1007s4Sa', 'S100vOnna'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  485: {'ids': array(['S1007s4Sa', 'S1008WtKa'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  486: {'ids': array(['S1007s4Sa', 'S1008WtKa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  487: {'ids': array(['S1006Sv1a', 'S1007s4Sa', 'S100qqVza'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  488: {'ids': array(['S1007s4Sa', 'S1009Mnra', 'S100vOnna'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  489: {'ids': array(['S1005tcxa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  490: {'ids': array(['S1005tcxa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  491: {'ids': array(['S1006Sv1a', 'S1007s4Sa', 'S1008WtKa', 'S100jKVVa'], dtype=object),
#   'n_trks': 129,
#   'rating': 4},
#  492: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 8, 'rating': 1},
#  493: {'ids': array(['S1006Sv1a', 'S1007s4Sa', 'S1008WtKa', 'S1008s62a', 'S1009Mnra',
#          'S100aPbZa', 'S100jKVVa'], dtype=object),
#   'n_trks': 108,
#   'rating': 7},
#  494: {'ids': array(['S1007s4Sa', 'S1008WtKa', 'S100vOnna'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  495: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  496: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  497: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  498: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  499: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  500: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  501: {'ids': array(['S1007s4Sa', 'S1009Mnra', 'S100vOnna'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  502: {'ids': array(['S1002YOIa', 'S100LncOa', 'S100ysz0a'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  503: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  504: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  505: {'ids': array(['S1002YOIa', 'S100LncOa', 'S100ysz0a'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  506: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  507: {'ids': array(['S100ysz0a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  508: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  509: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 78, 'rating': 1},
#  510: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  511: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 37, 'rating': 1},
#  512: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  513: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  514: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  515: {'ids': array(['S1009Mnra'], dtype=object), 'n_trks': 3, 'rating': 1},
#  516: {'ids': array(['S1009Mnra'], dtype=object), 'n_trks': 3, 'rating': 1},
#  517: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  518: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  519: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  520: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  521: {'ids': array(['S100LncOa', 'S100ysz0a'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  522: {'ids': array(['S1009Mnra', 'S100tM77a'], dtype=object),
#   'n_trks': 8,
#   'rating': 2},
#  523: {'ids': array(['S1003vw8a', 'S1009Mnra'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  524: {'ids': array(['S1009Mnra', 'S100tM77a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  525: {'ids': array(['S1009Mnra'], dtype=object), 'n_trks': 3, 'rating': 1},
#  526: {'ids': array(['S1008s62a', 'S1009Mnra'], dtype=object),
#   'n_trks': 11,
#   'rating': 2},
#  527: {'ids': array(['S1008WtKa', 'S1008s62a', 'S1009Mnra', 'S100jKVVa'], dtype=object),
#   'n_trks': 47,
#   'rating': 4},
#  528: {'ids': array(['S1009Mnra'], dtype=object), 'n_trks': 3, 'rating': 1},
#  529: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  530: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  531: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  532: {'ids': array(['S1009Mnra'], dtype=object), 'n_trks': 4, 'rating': 1},
#  533: {'ids': array(['S1008WtKa', 'S100jKVVa'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  534: {'ids': array(['S1007s4Sa', 'S1008WtKa', 'S100jKVVa'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  535: {'ids': array(['S1008WtKa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  536: {'ids': array(['S1008WtKa', 'S100vOnna'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  537: {'ids': array(['S1008WtKa', 'S100jKVVa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  538: {'ids': array(['S1008WtKa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  539: {'ids': array(['S1006Sv1a', 'S1007s4Sa', 'S1008WtKa'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  540: {'ids': array(['S1008WtKa', 'S1009Mnra', 'S100tM77a'], dtype=object),
#   'n_trks': 7,
#   'rating': 3},
#  541: {'ids': array(['S1008WtKa', 'S1008s62a', 'S1009Mnra'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  542: {'ids': array(['S100LncOa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  543: {'ids': array(['S1008s62a', 'S100tM77a'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  544: {'ids': array(['S1008s62a'], dtype=object), 'n_trks': 16, 'rating': 1},
#  545: {'ids': array(['S1008s62a'], dtype=object), 'n_trks': 7, 'rating': 1},
# ...
#   'n_trks': 5,
#   'rating': 2},
#  804: {'ids': array(['S100k7m6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  805: {'ids': array(['S100k7m6a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  806: {'ids': array(['S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  807: {'ids': array(['S1009Bg3a', 'S100cRDla', 'S100gTIUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  808: {'ids': array(['S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  809: {'ids': array(['S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  810: {'ids': array(['S1000UbZa', 'S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 535,
#   'rating': 3},
#  811: {'ids': array(['S100fWcEa', 'S100k7m6a'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  812: {'ids': array(['S100k7m6a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  813: {'ids': array(['S100fWcEa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  814: {'ids': array(['S100fWcEa'], dtype=object), 'n_trks': 6, 'rating': 1},
#  815: {'ids': array(['S100fWcEa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  816: {'ids': array(['S100fWcEa', 'S100gxERa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  817: {'ids': array(['S100fWcEa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  818: {'ids': array(['S100fWcEa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  819: {'ids': array(['S100fWcEa', 'S100gxERa'], dtype=object),
#   'n_trks': 7,
#   'rating': 2},
#  820: {'ids': array(['S100fWcEa', 'S100k7m6a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  821: {'ids': array(['S1004z2Ea', 'S100drYXa', 'S100gvBUa'], dtype=object),
#   'n_trks': 4,
#   'rating': 3},
#  822: {'ids': array(['S100gvBUa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  823: {'ids': array(['S1004z2Ea', 'S100gvBUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  824: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 12, 'rating': 1},
#  825: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 10, 'rating': 1},
#  826: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 9, 'rating': 1},
#  827: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 4, 'rating': 1},
#  828: {'ids': array(['S1004z2Ea', 'S100drYXa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  829: {'ids': array(['S100drYXa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  830: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 4, 'rating': 1},
#  831: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 12, 'rating': 1},
#  832: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  833: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 6, 'rating': 1},
#  834: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 7, 'rating': 1},
#  835: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  836: {'ids': array(['S1005qCJa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  837: {'ids': array(['S1005qCJa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  838: {'ids': array(['S1005qCJa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  839: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 4, 'rating': 1},
#  840: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  841: {'ids': array(['S100Bthia'], dtype=object), 'n_trks': 4, 'rating': 1},
#  842: {'ids': array(['S1003RsPa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  843: {'ids': array(['S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  844: {'ids': array(['S1003ij0a', 'S1009Bg3a', 'S100gTIUa'], dtype=object),
#   'n_trks': 6,
#   'rating': 3},
#  845: {'ids': array(['S100cRDla'], dtype=object), 'n_trks': 3, 'rating': 1},
#  846: {'ids': array(['S100cRDla'], dtype=object), 'n_trks': 4, 'rating': 1},
#  847: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  848: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 6, 'rating': 1},
#  849: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  850: {'ids': array(['S100267Da', 'S1003ij0a', 'S1009Bg3a'], dtype=object),
#   'n_trks': 8,
#   'rating': 3},
#  851: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 6, 'rating': 1},
#  852: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  853: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  854: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  855: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  856: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  857: {'ids': array(['S1000UbZa', 'S100267Da', 'S1003ij0a', 'S1009Bg3a'], dtype=object),
#   'n_trks': 841,
#   'rating': 4},
#  858: {'ids': array(['S1000UbZa', 'S1009Bg3a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  859: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 4, 'rating': 1},
#  860: {'ids': array(['S1000UbZa', 'S1009Bg3a'], dtype=object),
#   'n_trks': 20,
#   'rating': 2},
#  861: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  862: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  863: {'ids': array(['S1009Bg3a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  864: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  865: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  866: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  867: {'ids': array(['S1000UbZa', 'S1009Bg3a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  868: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  869: {'ids': array(['S100267Da', 'S1003ij0a', 'S1009Bg3a'], dtype=object),
#   'n_trks': 3,
#   'rating': 3},
#  870: {'ids': array(['S1003eDca'], dtype=object), 'n_trks': 376, 'rating': 1},
#  871: {'ids': array(['S1003eDca'], dtype=object), 'n_trks': 6, 'rating': 1},
#  872: {'ids': array(['S1003eDca', 'S1004xu6a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  873: {'ids': array(['S100267Da', 'S1003ij0a'], dtype=object),
#   'n_trks': 6,
#   'rating': 2},
#  874: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  875: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  876: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  877: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  878: {'ids': array(['S1000UbZa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  879: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 5, 'rating': 1},
#  880: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 282, 'rating': 1},
#  881: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  882: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 7, 'rating': 1},
#  883: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 4, 'rating': 1},
#  884: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  885: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  886: {'ids': array(['S100267Da', 'S1003ij0a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  887: {'ids': array(['S1003ij0a', 'S1009Bg3a'], dtype=object),
#   'n_trks': 7,
#   'rating': 2},
#  888: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  889: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  890: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  891: {'ids': array(['S100BV8ha'], dtype=object), 'n_trks': 3, 'rating': 1},
#  892: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 38, 'rating': 1},
#  893: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 39, 'rating': 1},
#  894: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 9, 'rating': 1},
#  895: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  896: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  897: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  898: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 8, 'rating': 1},
#  899: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  900: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 11, 'rating': 1},
#  901: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 5, 'rating': 1},
#  902: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  903: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 7, 'rating': 1},
#  904: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  905: {'ids': array(['S100267Da', 'S1003ij0a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  906: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  907: {'ids': array(['S100gxERa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  908: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 533, 'rating': 1},
#  909: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 12, 'rating': 1},
#  910: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  911: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  912: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 3, 'rating': 1},
#  913: {'ids': array(['S100Crgva'], dtype=object), 'n_trks': 4, 'rating': 1},
#  914: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 23, 'rating': 1},
#  915: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  916: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 8, 'rating': 1},
#  917: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  918: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  919: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 6, 'rating': 1},
#  920: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 6, 'rating': 1},
#  921: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 6, 'rating': 1},
#  922: {'ids': array(['S1002esia', 'S100aMxFa'], dtype=object),
#   'n_trks': 5,
#   'rating': 2},
#  923: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  924: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 3, 'rating': 1},
#  925: {'ids': array(['S1002esia'], dtype=object), 'n_trks': 4, 'rating': 1},
#  926: {'ids': array(['S1005cWaa'], dtype=object), 'n_trks': 10, 'rating': 1},
#  927: {'ids': array(['S1005cWaa'], dtype=object), 'n_trks': 17, 'rating': 1},
#  928: {'ids': array(['S1005cWaa'], dtype=object), 'n_trks': 4, 'rating': 1},
#  929: {'ids': array(['S1006qRka', 'S100iCpoa'], dtype=object),
#   'n_trks': 4,
#   'rating': 2},
#  930: {'ids': array(['S100DGbTa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  931: {'ids': array(['S1006PIha', 'S100eQZwa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#
'], dtype=object), 'n_trks': 3, 'rating': 1},
#  981: {'ids': array(['S1009554a'], dtype=object), 'n_trks': 5, 'rating': 1},
#  982: {'ids': array(['S1007FKba'], dtype=object), 'n_trks': 3, 'rating': 1},
#  983: {'ids': array(['S1007PKFa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  984: {'ids': array(['S100nZyqa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  985: {'ids': array(['S1000XAca', 'S100oZS0a'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  986: {'ids': array(['S100qeqUa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  987: {'ids': array(['S1000IVaa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  988: {'ids': array(['S1009V5Ja'], dtype=object), 'n_trks': 3, 'rating': 1},
#  989: {'ids': array(['S1001Mg6a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  990: {'ids': array(['S100rLSca'], dtype=object), 'n_trks': 3, 'rating': 1},
#  991: {'ids': array(['S100dcJTa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  992: {'ids': array(['S10089Sqa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  993: {'ids': array(['S100CUlZa', 'S100mUpYa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  994: {'ids': array(['S1002aNSa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  995: {'ids': array(['S10015rxa', 'S1001wSHa'], dtype=object),
#   'n_trks': 3,
#   'rating': 2},
#  996: {'ids': array(['S1005yC7a'], dtype=object), 'n_trks': 3, 'rating': 1},
#  997: {'ids': array(['S1004voEa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  998: {'ids': array(['S100aLPfa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  999: {'ids': array(['S1005Q1Pa'], dtype=object), 'n_trks': 3, 'rating': 1},
#  ...}

# %%
logger.setLevel( logging.INFO )
mean_states, counts = calculate_mean_states_2( dbscan_fit.labels_, L_E )

# %%
np.any(counts == 0.0), np.sum( counts ), np.any(mean_states == 0.0)
# Out:
# (False, 1912814.0, False)

# %%
mean_states
# Out:
# array([[-0.00462895, -0.00345086,  0.02370017,  0.02366618,  0.00304667,
#          0.00506592],
#        [-0.00548261, -0.00126943,  0.03132543, -0.02103724,  0.02372734,
#         -0.00272043],
#        [-0.00546051, -0.00126474,  0.03119876, -0.02022954,  0.02426948,
#         -0.0025568 ],
#        ...,
#        [-0.0021681 ,  0.00316397,  0.02126336,  0.02147791, -0.00059252,
#          0.00227815],
#        [ 0.00911051,  0.00364949,  0.03687614,  0.03463953, -0.01432809,
#         -0.00713994],
#        [-0.00227513,  0.00033303,  0.02894567,  0.00187481,  0.01074184,
#         -0.000178  ]])

# %%
# unique_labels = np.unique(clusters.labels_)[1:]
# counts = np.zeros( len(unique_labels) )
# for i, label in enumerate( unique_labels ):
#     if label != i:
#         print(i, np.unique(clusters.labels_)[i+1])

# for (label, _) in zip(clusters.labels_, clusters.components_):
# # for label in clusters.labels_:
#     if label != -1:
#         counts[label] += 1


# len(np.unique(clusters.labels_)[1:][counts == 0.0 ])
# Out:
# 4724

# %%
len( clusters.labels_), len(clusters.components_)
# Out:
# (1912814, 13466)

# %%
np.random.rand( 3, 10 ) * np.random.rand( 3, 10 )
# Out:
# array([[0.25722033, 0.28790878, 0.01166061, 0.23893145, 0.63000022,
#         0.3300459 , 0.00709297, 0.40323104, 0.34092054, 0.10568957],
#        [0.58105918, 0.0339664 , 0.1370016 , 0.01448471, 0.018097  ,
#         0.49076873, 0.67529429, 0.20299409, 0.03651175, 0.05045339],
#        [0.42210805, 0.1617699 , 0.15694712, 0.0026243 , 0.25416524,
#         0.11581138, 0.04689292, 0.24780549, 0.04963919, 0.42037164]])
